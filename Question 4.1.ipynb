# %%
import pyodbc
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb

# %%
conn=pyodbc.connect(
    'Driver={SQL Server};'
    'Server=DESKTOP-6433KGU\DAGMARA1;'
    'Database=AdventureWorks2019;'
    'Trusted_Connection=yes;'
)

# %%
df=pd.read_sql_query('SELECT*FROM employeesickleaveview2',conn)
# Out:
# C:\Users\Dagmara\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
df = pd.read_sql_query('SELECT*FROM employeesickleaveview',conn)
df1=df.sort_values(by=['Avg_SickLeaveHours'])
# Out:
# C:\Users\Dagmara\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df1.plot(kind='bar' , x='JobTitle');
df1.plot(kind='bar' , x='JobTitle', stacked=True, color={'Avg_SickLeaveHours':'orange'},figsize= (11,6));
